# %% [markdown]
# # Get Data

# %%
from google.colab import files
files.upload() # Here you upload your API Kaggle

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
# 100% 809M/812M [00:23<00:00, 39.9MB/s]
# 100% 812M/812M [00:23<00:00, 36.3MB/s]

# %%
# !unzip -qq dogs-vs-cats.zip

# %%
# !unzip -qq train.zip

# %% [markdown]
# # Create Dataset

# %%
import os, shutil, pathlib
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import image_dataset_from_directory
import matplotlib.pyplot as plt
from tensorflow.keras import layers
random.seed(42)

original_dir = pathlib.Path("train") # path to get origin data
new_base_dir = pathlib.Path("cats_vs_dogs_data") # path to create new data

# %%
# Folder path
dir_path = r'/content/train'

count_cat= 0
count_dog = 0
# Iterate directory
for path in os.listdir(dir_path):
    # Check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
      # Count dog and cat images in train folder
      if 'cat' in path:
        count_cat += 1
      else:
        count_dog +=1

print('Cat count:', count_cat)
print('Dog count:', count_dog)
# Out:
# Cat count: 12500
# Dog count: 12500

# %%
# Here we create train_index, val_index, test_index
total_index = [i for i in range(count_cat)]
random.shuffle(total_index)

test_index = total_index[int(len(total_index)*0.8):]

train_index = total_index[:int(len(total_index)*0.8)]
random.shuffle(train_index)

val_index = train_index[int(len(train_index)*0.8):]
train_index = train_index[:int(len(train_index)*0.8)]

# %%
# Check the lenght of each index list
len(train_index), len(val_index), len(test_index)
# Out:
# (8000, 2000, 2500)

# %%
# Create new folder for train, val, test data
def make_subset(subset_name, index):
  for category in ("cat", "dog"):
    dir = new_base_dir / subset_name / category # path to save new images
    os.makedirs(dir)
    fnames = [f"{category}.{i}.jpg" for i in index]

    for fname in fnames:
        shutil.copyfile(src = original_dir / fname, # where to get data
                        dst = dir / fname)   # where to save new data

make_subset("train", train_index)
make_subset("val", val_index)
make_subset("test", test_index)

# %%
# Using image_dataset_from_directory to read images
train_dataset = image_dataset_from_directory(
new_base_dir / "train",
image_size=(180, 180),
batch_size=32)

val_dataset = image_dataset_from_directory(
new_base_dir / "val",
image_size=(180, 180),
batch_size=32)

test_dataset = image_dataset_from_directory(
new_base_dir / "test",
image_size=(180, 180),
batch_size=32)
# Out:
# Found 16000 files belonging to 2 classes.
# Found 4000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
# Displaying some randomly training images with labels
plt.figure(figsize=(10, 10))

class_name = train_dataset.class_names
for images, labels in train_dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_name[labels[i]])
    plt.axis("off")

# %% [markdown]
# # Data Augmentation

# %%
# Create sequential for data augmentation
data_augmentation = keras.Sequential(
    [keras.layers.RandomFlip("horizontal"), # Applies horizontal flipping to a random 50% of the images that go through it
     keras.layers.RandomRotation(0.1), # Rotates the input images by a value
     keras.layers.RandomZoom(0.2)] # Rotates the input images by a value
     )

# Displaying some randomly augmented training images
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
  for i in range(12):
    augmented_images = data_augmentation(images)
    plt.subplot(3, 4, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# # Base Model

# %%
# Adding a data augmentation stage and build classifier
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
  residual = x
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.SeparableConv2D(size, 3, padding="same", kernel_initializer='he_uniform', use_bias=False)(x)

  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.SeparableConv2D(size, 3, padding="same", kernel_initializer='he_uniform', use_bias=False)(x)
  x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

  residual = layers.Conv2D(size, 1, strides=2, padding="same", kernel_initializer='he_uniform',use_bias=False)(residual)
  x = layers.add([x, residual])


x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(64, kernel_initializer='he_uniform')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 180, 180, 3)  0           ['input_2[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 180, 180, 3)  0           ['sequential[1][0]']
#
#  conv2d_6 (Conv2D)              (None, 176, 176, 32  2400        ['rescaling_1[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 176, 176, 32  128        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 176, 176, 32  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  separable_conv2d_10 (Separable  (None, 176, 176, 32  1312       ['activation_10[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_11 (BatchN  (None, 176, 176, 32  128        ['separable_conv2d_10[0][0]']
#  ormalization)                  )
#
#  activation_11 (Activation)     (None, 176, 176, 32  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  separable_conv2d_11 (Separable  (None, 176, 176, 32  1312       ['activation_11[0][0]']
#  Conv2D)                        )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 88, 88, 32)  0           ['separable_conv2d_11[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 88, 88, 32)   1024        ['conv2d_6[0][0]']
#
#  add_5 (Add)                    (None, 88, 88, 32)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 88, 88, 32)  128         ['add_5[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 88, 88, 32)   0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 88, 88, 64)  2336        ['activation_12[0][0]']
#  Conv2D)
#
#  batch_normalization_13 (BatchN  (None, 88, 88, 64)  256         ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 88, 88, 64)   0           ['batch_normalization_13[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 88, 88, 64)  4672        ['activation_13[0][0]']
#  Conv2D)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 44, 44, 64)  0           ['separable_conv2d_13[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 44, 44, 64)   2048        ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 44, 44, 64)   0           ['max_pooling2d_6[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 44, 44, 64)  256         ['add_6[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 44, 44, 64)   0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 44, 44, 128)  8768       ['activation_14[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 44, 44, 128)  512        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 44, 44, 128)  0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 44, 44, 128)  17536      ['activation_15[0][0]']
#  Conv2D)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 22, 22, 128)  0          ['separable_conv2d_15[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 22, 22, 128)  8192        ['add_6[0][0]']
#
#  add_7 (Add)                    (None, 22, 22, 128)  0           ['max_pooling2d_7[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 22, 22, 128)  512        ['add_7[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 22, 22, 128)  0           ['batch_normalization_16[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 22, 22, 256)  33920      ['activation_16[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 22, 22, 256)  1024       ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 22, 22, 256)  0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 22, 22, 256)  67840      ['activation_17[0][0]']
#  Conv2D)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 11, 11, 256)  0          ['separable_conv2d_17[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 11, 11, 256)  32768       ['add_7[0][0]']
#
#  add_8 (Add)                    (None, 11, 11, 256)  0           ['max_pooling2d_8[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 11, 11, 256)  1024       ['add_8[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 11, 11, 256)  0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 11, 11, 512)  133376     ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 11, 11, 512)  2048       ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 11, 11, 512)  0           ['batch_normalization_19[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 11, 11, 512)  266752     ['activation_19[0][0]']
#  Conv2D)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 6, 6, 512)   0           ['separable_conv2d_19[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 6, 6, 512)    131072      ['add_8[0][0]']
#
#  add_9 (Add)                    (None, 6, 6, 512)    0           ['max_pooling2d_9[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 512)         0           ['add_9[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 64)           32832       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            65          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 754,241
# Trainable params: 751,233
# Non-trainable params: 3,008
# __________________________________________________________________________________________________

# %%
# Training the model with callbacks
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"])

callbacks = [
    # ModelCheckpoint help you save your model based on your condition
    keras.callbacks.ModelCheckpoint(
        filepath="base_model.keras",  # File name
        save_best_only=True, # Only save the best one
        monitor="val_accuracy" # Condition for callbacks follow
        ),

    # ReduceLROnPlateau help you change the learning rate based on your condition
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', # Condition for changing leanring rate
        factor= 0.1,  # new_leanrning_rate = factor * current_leanrning_rate
        patience= 5 # Consider the monitor on the 5 epoch
        )
    ]

history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=val_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 83s 147ms/step - loss: 0.7230 - accuracy: 0.5872 - val_loss: 0.7030 - val_accuracy: 0.5082 - lr: 0.0010
# Epoch 2/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.6048 - accuracy: 0.6750 - val_loss: 1.0051 - val_accuracy: 0.5368 - lr: 0.0010
# Epoch 3/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.5116 - accuracy: 0.7541 - val_loss: 0.4817 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 4/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.4390 - accuracy: 0.8021 - val_loss: 0.6348 - val_accuracy: 0.7072 - lr: 0.0010
# Epoch 5/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.3820 - accuracy: 0.8294 - val_loss: 0.4922 - val_accuracy: 0.7448 - lr: 0.0010
# Epoch 6/50
# 500/500 [==============================] - 69s 138ms/step - loss: 0.3400 - accuracy: 0.8507 - val_loss: 0.6755 - val_accuracy: 0.7255 - lr: 0.0010
# Epoch 7/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.3048 - accuracy: 0.8714 - val_loss: 0.3170 - val_accuracy: 0.8637 - lr: 0.0010
# Epoch 8/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.2788 - accuracy: 0.8805 - val_loss: 0.3095 - val_accuracy: 0.8675 - lr: 0.0010
# Epoch 9/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.2656 - accuracy: 0.8863 - val_loss: 0.2838 - val_accuracy: 0.8890 - lr: 0.0010
# Epoch 10/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.2426 - accuracy: 0.8975 - val_loss: 0.2835 - val_accuracy: 0.8767 - lr: 0.0010
# Epoch 11/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.2267 - accuracy: 0.9055 - val_loss: 0.2229 - val_accuracy: 0.9145 - lr: 0.0010
# Epoch 12/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.2161 - accuracy: 0.9106 - val_loss: 0.2025 - val_accuracy: 0.9210 - lr: 0.0010
# Epoch 13/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.2070 - accuracy: 0.9153 - val_loss: 0.2387 - val_accuracy: 0.8990 - lr: 0.0010
# Epoch 14/50
# 500/500 [==============================] - 67s 133ms/step - loss: 0.1975 - accuracy: 0.9164 - val_loss: 0.1981 - val_accuracy: 0.9210 - lr: 0.0010
# Epoch 15/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.1912 - accuracy: 0.9216 - val_loss: 0.1741 - val_accuracy: 0.9360 - lr: 0.0010
# Epoch 16/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.1802 - accuracy: 0.9268 - val_loss: 0.2604 - val_accuracy: 0.9025 - lr: 0.0010
# Epoch 17/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.1774 - accuracy: 0.9286 - val_loss: 0.1548 - val_accuracy: 0.9405 - lr: 0.0010
# Epoch 18/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.1682 - accuracy: 0.9319 - val_loss: 0.2288 - val_accuracy: 0.9080 - lr: 0.0010
# Epoch 19/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.1632 - accuracy: 0.9349 - val_loss: 0.1637 - val_accuracy: 0.9333 - lr: 0.0010
# Epoch 20/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1623 - accuracy: 0.9344 - val_loss: 0.2094 - val_accuracy: 0.9180 - lr: 0.0010
# Epoch 21/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1473 - accuracy: 0.9406 - val_loss: 0.1820 - val_accuracy: 0.9275 - lr: 0.0010
# Epoch 22/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.1472 - accuracy: 0.9396 - val_loss: 0.1542 - val_accuracy: 0.9423 - lr: 0.0010
# Epoch 23/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1409 - accuracy: 0.9411 - val_loss: 0.1882 - val_accuracy: 0.9212 - lr: 0.0010
# Epoch 24/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.1382 - accuracy: 0.9433 - val_loss: 0.1617 - val_accuracy: 0.9345 - lr: 0.0010
# Epoch 25/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.1358 - accuracy: 0.9461 - val_loss: 0.3355 - val_accuracy: 0.8687 - lr: 0.0010
# Epoch 26/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.1309 - accuracy: 0.9488 - val_loss: 0.1236 - val_accuracy: 0.9513 - lr: 0.0010
# Epoch 27/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.1268 - accuracy: 0.9488 - val_loss: 0.1712 - val_accuracy: 0.9342 - lr: 0.0010
# Epoch 28/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1333 - accuracy: 0.9465 - val_loss: 0.1800 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 29/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.1220 - accuracy: 0.9522 - val_loss: 0.1478 - val_accuracy: 0.9400 - lr: 0.0010
# Epoch 30/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.1251 - accuracy: 0.9487 - val_loss: 0.1955 - val_accuracy: 0.9260 - lr: 0.0010
# Epoch 31/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.1181 - accuracy: 0.9526 - val_loss: 0.1481 - val_accuracy: 0.9352 - lr: 0.0010
# Epoch 32/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0874 - accuracy: 0.9646 - val_loss: 0.0970 - val_accuracy: 0.9647 - lr: 1.0000e-04
# Epoch 33/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.0790 - accuracy: 0.9680 - val_loss: 0.0952 - val_accuracy: 0.9630 - lr: 1.0000e-04
# Epoch 34/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0727 - accuracy: 0.9728 - val_loss: 0.0907 - val_accuracy: 0.9685 - lr: 1.0000e-04
# Epoch 35/50
# 500/500 [==============================] - 69s 138ms/step - loss: 0.0715 - accuracy: 0.9720 - val_loss: 0.0873 - val_accuracy: 0.9685 - lr: 1.0000e-04
# Epoch 36/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.0674 - accuracy: 0.9737 - val_loss: 0.0879 - val_accuracy: 0.9685 - lr: 1.0000e-04
# Epoch 37/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0632 - accuracy: 0.9753 - val_loss: 0.0909 - val_accuracy: 0.9678 - lr: 1.0000e-04
# Epoch 38/50
# 500/500 [==============================] - 69s 136ms/step - loss: 0.0640 - accuracy: 0.9754 - val_loss: 0.0845 - val_accuracy: 0.9707 - lr: 1.0000e-04
# Epoch 39/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0650 - accuracy: 0.9744 - val_loss: 0.0862 - val_accuracy: 0.9693 - lr: 1.0000e-04
# Epoch 40/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.0596 - accuracy: 0.9762 - val_loss: 0.0845 - val_accuracy: 0.9720 - lr: 1.0000e-04
# Epoch 41/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0601 - accuracy: 0.9766 - val_loss: 0.0881 - val_accuracy: 0.9697 - lr: 1.0000e-04
# Epoch 42/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.0596 - accuracy: 0.9774 - val_loss: 0.0850 - val_accuracy: 0.9705 - lr: 1.0000e-04
# Epoch 43/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.0561 - accuracy: 0.9780 - val_loss: 0.0815 - val_accuracy: 0.9720 - lr: 1.0000e-04
# Epoch 44/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0528 - accuracy: 0.9779 - val_loss: 0.0904 - val_accuracy: 0.9690 - lr: 1.0000e-04
# Epoch 45/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.0580 - accuracy: 0.9778 - val_loss: 0.0949 - val_accuracy: 0.9672 - lr: 1.0000e-04
# Epoch 46/50
# 500/500 [==============================] - 68s 135ms/step - loss: 0.0522 - accuracy: 0.9796 - val_loss: 0.0836 - val_accuracy: 0.9697 - lr: 1.0000e-04
# Epoch 47/50
# 500/500 [==============================] - 68s 136ms/step - loss: 0.0511 - accuracy: 0.9802 - val_loss: 0.0889 - val_accuracy: 0.9682 - lr: 1.0000e-04
# Epoch 48/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.0555 - accuracy: 0.9798 - val_loss: 0.0908 - val_accuracy: 0.9685 - lr: 1.0000e-04
# Epoch 49/50
# 500/500 [==============================] - 67s 134ms/step - loss: 0.0496 - accuracy: 0.9814 - val_loss: 0.0908 - val_accuracy: 0.9693 - lr: 1.0000e-05
# Epoch 50/50
# 500/500 [==============================] - 69s 137ms/step - loss: 0.0476 - accuracy: 0.9821 - val_loss: 0.0896 - val_accuracy: 0.9693 - lr: 1.0000e-05

# %%
# Displaying curves of loss and accuracy during training
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.figure(figsize = (15,5))
plt.subplot(121)
plt.plot(epochs, accuracy, "ro", label="Training accuracy")
plt.plot(epochs, val_accuracy, "r", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(122)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
# Evaluating the model on the test set
model_1 = keras.models.load_model("base_model.keras")
test_loss, test_acc = model_1.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
print(f"Test loss: {test_loss:.3f}")
# Out:
# 157/157 [==============================] - 8s 50ms/step - loss: 0.0958 - accuracy: 0.9632
# Test accuracy: 0.963
# Test loss: 0.096
